# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import numpy as np
import os
import matplotlib.pyplot as plt
from models import *
from configs import cfg
import pandas as pd
from nltk.translate import bleu_score

# %%
def load_data(fname):
    # From the csv file given by filename and return a pandas DataFrame of the read csv.
    
    # Define path to data
    # Note: Path relative to KHIEM's files, make changes to relative path if necessary
    dataPath = 'BeerAdvocatePA4/' + fname
    
    # Read csv into pandas frame
    df = pd.read_csv(dataPath)
    
    # Return frame
    return df


def process_train_data(data):
    # TODO: Input is a pandas DataFrame and return a numpy array (or a torch Tensor/ Variable)
    # that has all features (including characters in one hot encoded form).
    raise NotImplementedError

    
def train_valid_split(data, labels):
    # TODO: Takes in train data and labels as numpy array (or a torch Tensor/ Variable) and
    # splits it into training and validation data.
    raise NotImplementedError
    
    
def process_test_data(data):
    # TODO: Takes in pandas DataFrame and returns a numpy array (or a torch Tensor/ Variable)
    # that has all input features. Note that test data does not contain any review so you don't
    # have to worry about one hot encoding the data.
    raise NotImplementedError

    
def pad_data(orig_data):
    # TODO: Since you will be training in batches and training sample of each batch may have reviews
    # of varying lengths, you will need to pad your data so that all samples have reviews of length
    # equal to the longest review in a batch. You will pad all the sequences with <EOS> character 
    # representation in one hot encoding.
    raise NotImplementedError
    

def train(model, X_train, y_train, X_valid, y_valid, cfg):
    # TODO: Train the model!
    raise NotImplementedError
    
    
def generate(model, X_test, cfg):
    # TODO: Given n rows in test data, generate a list of n strings, where each string is the review
    # corresponding to each input row in test data.
    raise NotImplementedError
    
    
def save_to_file(outputs, fname):
    # TODO: Given the list of generated review outputs and output file name, save all these reviews to
    # the file in .txt format.
    raise NotImplementedError

# %%
if __name__ == "__main__":
    train_data_fname = "Beeradvocate_train.csv"
    test_data_fname = "Beeradvocate_test.csv"
    out_fname = "model_outputs.out"
    
    train_data = load_data(train_data_fname) # Generating the pandas DataFrame
    test_data = load_data(test_data_fname) # Generating the pandas DataFrame
    train_data, train_labels = process_train_data(train_data) # Converting DataFrame to numpy array
    X_train, y_train, X_valid, y_valid = train_valid_split(train_data, train_labels) # Splitting the train data into train-valid data
    X_test = process_test_data(test_data) # Converting DataFrame to numpy array
    
    model = baselineLSTM(cfg) # Replace this with model = <your model name>(cfg)
    if cfg['cuda']:
        computing_device = torch.device("cuda")
    else:
        computing_device = torch.device("cpu")
    model.to(computing_device)
    
    train(model, X_train, y_train, X_valid, y_valid, cfg) # Train the model
    outputs = generate(model, X_test, cfg) # Generate the outputs for test data
    save_to_file(outputs, out_fname) # Save the generated outputs to a file
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-763299f7153a> in <module>
#       6     train_data = load_data(train_data_fname) # Generating the pandas DataFrame
#       7     test_data = load_data(test_data_fname) # Generating the pandas DataFrame
# ----> 8     train_data, train_labels = process_train_data(train_data) # Converting DataFrame to numpy array
#       9     X_train, y_train, X_valid, y_valid = train_valid_split(train_data, train_labels) # Splitting the train data into train-valid data
#      10     X_test = process_test_data(test_data) # Converting DataFrame to numpy array
#
# <ipython-input-6-7ce4bfe0795f> in process_train_data(data)
#      16     # TODO: Input is a pandas DataFrame and return a numpy array (or a torch Tensor/ Variable)
#      17     # that has all features (including characters in one hot encoded form).
# ---> 18     raise NotImplementedError
#      19
#      20
#
# NotImplementedError:

# %%
test = load_data(test_data_fname)
train = load_data(train_data_fname)

# %%
# Out:
#          Unnamed: 0               beer/name  beer/beerId  beer/brewerId  \
# 0                 0            Sausa Weizen        47986          10325
# 1                 1                Red Moon        48213          10325
# 2                 2  Black Horse Black Beer        48215          10325
# 3                 3              Sausa Pils        47969          10325
# 4                 4           Cauldron DIPA        64883           1075
# 5                 5     Caldera Ginger Beer        52159           1075
# 6                 6     Caldera Ginger Beer        52159           1075
# 7                 7     Caldera Ginger Beer        52159           1075
# 8                 8     Caldera Ginger Beer        52159           1075
# 9                 9     Caldera Ginger Beer        52159           1075
# 10               10     Caldera Ginger Beer        52159           1075
# 11               11     Caldera Ginger Beer        52159           1075
# 12               12     Caldera Ginger Beer        52159           1075
# 13               13     Caldera Ginger Beer        52159           1075
# 14               14   Caldera Oatmeal Stout        10789           1075
# 15               15   Caldera Oatmeal Stout        10789           1075
# 16               16          Caldera OBF 15        12386           1075
# 17               17           Rauch Ür Bock        58046           1075
# 18               18           Rauch Ür Bock        58046           1075
# 19               19           Rauch Ür Bock        58046           1075
# 20               20           Rauch Ür Bock        58046           1075
# 21               21           Rauch Ür Bock        58046           1075
# 22               22           Rauch Ür Bock        58046           1075
# 23               23           Rauch Ür Bock        58046           1075
# 24               24           Rauch Ür Bock        58046           1075
# 25               25           Rauch Ür Bock        58046           1075
# 26               26           Rauch Ür Bock        58046           1075
# 27               27           Rauch Ür Bock        58046           1075
# 28               28           Rauch Ür Bock        58046           1075
# 29               29           Rauch Ür Bock        58046           1075
# ...             ...                     ...          ...            ...
# 1269261     1269261        Old Speckled Hen          637            203
# 1269262     1269262        Old Speckled Hen          637            203
# 1269263     1269263        Old Speckled Hen          637            203
# 1269264     1269264        Old Speckled Hen          637            203
# 1269265     1269265        Old Speckled Hen          637            203
# 1269266     1269266        Old Speckled Hen          637            203
# 1269267     1269267        Old Speckled Hen          637            203
# 1269268     1269268        Old Speckled Hen          637            203
# 1269269     1269269        Old Speckled Hen          637            203
# 1269270     1269270        Old Speckled Hen          637            203
# 1269271     1269271        Old Speckled Hen          637            203
# 1269272     1269272        Old Speckled Hen          637            203
# 1269273     1269273        Old Speckled Hen          637            203
# 1269274     1269274        Old Speckled Hen          637            203
# 1269275     1269275        Old Speckled Hen          637            203
# 1269276     1269276        Old Speckled Hen          637            203
# 1269277     1269277        Old Speckled Hen          637            203
# 1269278     1269278        Old Speckled Hen          637            203
# 1269279     1269279        Old Speckled Hen          637            203
# 1269280     1269280        Old Speckled Hen          637            203
# 1269281     1269281        Old Speckled Hen          637            203
# 1269282     1269282        Old Speckled Hen          637            203
# 1269283     1269283        Old Speckled Hen          637            203
# 1269284     1269284        Old Speckled Hen          637            203
# 1269285     1269285        Old Speckled Hen          637            203
# 1269286     1269286        Old Speckled Hen          637            203
# 1269287     1269287        Old Speckled Hen          637            203
# 1269288     1269288        Old Speckled Hen          637            203
# 1269289     1269289        Old Speckled Hen          637            203
# 1269290     1269290        Old Speckled Hen          637            203
#
#          beer/ABV                      beer/style  review/appearance  \
# 0             5.0                      Hefeweizen                2.5
# 1             6.2              English Strong Ale                3.0
# 2             6.5          Foreign / Export Stout                3.0
# 3             5.0                 German Pilsener                3.5
# 4             7.7  American Double / Imperial IPA                4.0
# 5             4.7            Herbed / Spiced Beer                3.5
# 6             4.7            Herbed / Spiced Beer                3.5
# 7             4.7            Herbed / Spiced Beer                3.5
# 8             4.7            Herbed / Spiced Beer                3.5
# 9             4.7            Herbed / Spiced Beer                5.0
# 10            4.7            Herbed / Spiced Beer                4.0
# 11            4.7            Herbed / Spiced Beer                4.0
# 12            4.7            Herbed / Spiced Beer                3.0
# 13            4.7            Herbed / Spiced Beer                3.0
# 14            7.2                   Oatmeal Stout                2.5
# 15            7.2                   Oatmeal Stout                2.5
# 16            5.6             American Pale Lager                4.0
# 17            7.4                       Rauchbier                3.0
# 18            7.4                       Rauchbier                4.0
# 19            7.4                       Rauchbier                4.0
# 20            7.4                       Rauchbier                4.5
# 21            7.4                       Rauchbier                4.0
# 22            7.4                       Rauchbier                4.0
# 23            7.4                       Rauchbier                3.5
# 24            7.4                       Rauchbier                4.0
# 25            7.4                       Rauchbier                4.0
# 26            7.4                       Rauchbier                3.5
# 27            7.4                       Rauchbier                4.0
# 28            7.4                       Rauchbier                4.0
# 29            7.4                       Rauchbier                4.5
# ...           ...                             ...                ...
# 1269261       5.2                English Pale Ale                4.5
# 1269262       5.2                English Pale Ale                4.5
# 1269263       5.2                English Pale Ale                4.5
# 1269264       5.2                English Pale Ale                3.0
# 1269265       5.2                English Pale Ale                3.5
# 1269266       5.2                English Pale Ale                4.5
# 1269267       5.2                English Pale Ale                3.0
# 1269268       5.2                English Pale Ale                4.0
# 1269269       5.2                English Pale Ale                4.0
# 1269270       5.2                English Pale Ale                3.5
# 1269271       5.2                English Pale Ale                5.0
# 1269272       5.2                English Pale Ale                4.0
# 1269273       5.2                English Pale Ale                4.5
# 1269274       5.2                English Pale Ale                4.5
# 1269275       5.2                English Pale Ale                4.5
# 1269276       5.2                English Pale Ale                4.0
# 1269277       5.2                English Pale Ale                4.5
# 1269278       5.2                English Pale Ale                4.0
# 1269279       5.2                English Pale Ale                4.5
# 1269280       5.2                English Pale Ale                3.0
# 1269281       5.2                English Pale Ale                3.5
# 1269282       5.2                English Pale Ale                3.5
# 1269283       5.2                English Pale Ale                4.0
# 1269284       5.2                English Pale Ale                2.5
# 1269285       5.2                English Pale Ale                3.0
# 1269286       5.2                English Pale Ale                3.5
# 1269287       5.2                English Pale Ale                4.0
# 1269288       5.2                English Pale Ale                3.5
# 1269289       5.2                English Pale Ale                3.5
# 1269290       5.2                English Pale Ale                4.0
#
#          review/aroma  review/palate  review/taste  review/overall  \
# 0                 2.0            1.5           1.5             1.5
# 1                 2.5            3.0           3.0             3.0
# 2                 2.5            3.0           3.0             3.0
# 3                 3.0            2.5           3.0             3.0
# 4                 4.5            4.0           4.5             4.0
# 5                 3.5            3.0           3.5             3.0
# 6                 3.5            4.0           4.0             3.5
# 7                 2.5            2.0           3.5             3.0
# 8                 3.0            3.5           4.0             4.0
# 9                 3.5            4.0           4.0             4.5
# 10                5.0            4.0           4.0             5.0
# 11                4.0            3.5           4.0             4.0
# 12                4.5            2.5           3.0             4.0
# 13                4.0            3.0           4.0             3.5
# 14                3.0            3.0           3.0             3.0
# 15                1.5            2.5           2.0             2.0
# 16                3.0            4.0           4.0             4.0
# 17                4.5            4.0           4.5             4.5
# 18                4.0            3.0           4.0             4.0
# 19                4.5            3.5           4.0             4.0
# 20                5.0            4.0           4.5             4.5
# 21                4.5            4.0           4.5             4.0
# 22                4.5            4.0           4.5             4.5
# 23                5.0            3.5           5.0             5.0
# 24                4.5            4.0           4.5             4.5
# 25                5.0            4.0           4.0             4.5
# 26                4.5            4.0           4.5             4.5
# 27                4.5            4.0           4.0             4.5
# 28                4.5            4.0           5.0             5.0
# 29                4.0            4.0           4.0             4.0
# ...               ...            ...           ...             ...
# 1269261           3.5            4.0           3.5             3.5
# 1269262           3.0            5.0           3.0             3.5
# 1269263           3.5            4.5           5.0             4.5
# 1269264           3.5            2.5           3.5             3.0
# 1269265           3.5            3.5           3.5             3.5
# 1269266           3.5            3.5           4.0             4.0
# 1269267           3.0            4.0           3.5             4.0
# 1269268           4.0            3.5           4.0             4.0
# 1269269           3.5            3.5           3.5             3.5
# 1269270           3.5            4.0           3.5             4.0
# 1269271           4.0            3.5           4.0             4.0
# 1269272           2.5            2.5           2.5             3.5
# 1269273           3.0            4.0           4.0             4.5
# 1269274           3.0            3.0           3.0             3.0
# 1269275           4.0            4.0           4.0             4.0
# 1269276           4.5            4.0           4.0             5.0
# 1269277           3.5            3.5           3.0             4.0
# 1269278           4.0            3.5           4.0             4.0
# 1269279           4.0            3.5           4.0             4.0
# 1269280           5.0            5.0           5.0             5.0
# 1269281           3.0            2.5           2.0             2.5
# 1269282           3.0            3.5           4.0             4.5
# 1269283           3.0            3.0           4.0             4.5
# 1269284           2.0            2.0           1.5             2.5
# 1269285           3.0            3.0           3.5             3.0
# 1269286           3.0            3.5           4.0             4.0
# 1269287           4.5            3.5           4.0             4.5
# 1269288           3.5            3.5           3.5             4.5
# 1269289           4.0            3.5           3.0             3.0
# 1269290           4.0            2.5           3.5             4.0
#
#          review/time review/profileName  \
# 0         1234817823            stcules
# 1         1235915097            stcules
# 2         1235916604            stcules
# 3         1234725145            stcules
# 4         1293735206     johnmichaelsen
# 5         1325524659            oline73
# 6         1318991115          Reidrover
# 7         1306276018       alpinebryant
# 8         1290454503      LordAdmNelson
# 9         1285632924       augustgarage
# 10        1283154365       MadeInOregon
# 11        1277557990            rawthar
# 12        1275779250        Halcyondays
# 13        1273109020        RangerClegg
# 14        1316025612   Beerandraiderfan
# 15        1103502339         RedDiamond
# 16        1062311123         beerguy101
# 17        1325478004        UCLABrewN84
# 18        1325360812         zaphodchak
# 19        1322506304            Tilley4
# 20        1320494397    mikedrinksbeer2
# 21        1320140421         dbmernin83
# 22        1319847514     titosupertramp
# 23        1318802642        optimator13
# 24        1318290101          Blakaeris
# 25        1318289482            bashiba
# 26        1316405909               Klym
# 27        1315696563          flexabull
# 28        1315014054               Bung
# 29        1314752229             oberon
# ...              ...                ...
# 1269261   1252801673            Jwale73
# 1269262   1252636420          LittleDon
# 1269263   1252462169             drperm
# 1269264   1252001752              Jeffo
# 1269265   1251859356               sbe1
# 1269266   1251647373         garymuchow
# 1269267   1251572520       scottyshades
# 1269268   1251514022      bluemoonswoon
# 1269269   1251243233      Seanstoppable
# 1269270   1250981634           bigdeuce
# 1269271   1250133972     electricfields
# 1269272   1249787842              katan
# 1269273   1249630440           Evocatus
# 1269274   1249610938          KenOnBass
# 1269275   1249493752               Offa
# 1269276   1249493213               Offa
# 1269277   1249348034           Shango42
# 1269278   1249216309               GJ40
# 1269279   1249002482               srrn
# 1269280   1248746908         holyfool22
# 1269281   1248603618         mikeal1917
# 1269282   1248492187              NODAK
# 1269283   1248313321           kegger22
# 1269284   1248231858         photogadam
# 1269285   1247518905        WakeandBake
# 1269286   1247177111        Whiteweasel
# 1269287   1246274774                DT7
# 1269288   1245617512              seand
# 1269289   1245565535        donteatpoop
# 1269290   1244992606            Cresant
#
#                                                review/text
# 0        A lot of foam. But a lot.\tIn the smell some b...
# 1        Dark red color, light beige foam, average.\tIn...
# 2        Almost totally black. Beige foam, quite compac...
# 3        Golden yellow color. White, compact foam, quit...
# 4        According to the website, the style for the Ca...
# 5        Poured from the bottle into a Chimay goblet.\t...
# 6        22 oz bottle from "Lifesource" Salem. $3.95 Ni...
# 7        Bottle says "Malt beverage brewed with Ginger ...
# 8        I'm not sure why I picked this up... I like gi...
# 9        Poured from a 22oz bomber into my Drie Fontein...
# 10       OK, so the only reason I bought this while sho...
# 11       Notes from 6/24\t\tA: Bright golden glowing be...
# 12       22 oz. bomber,\t\tA: Pours a clear yellow with...
# 13       Is it possible for a bottle to be a novelty pr...
# 14       Brown in color, somewhere between a porter and...
# 15       Caldera presents yet another circumstance wher...
# 16       More of a 'dry' than a lager, tasted at the 20...
# 17       Pours a murky light brown with a 1 inch fizzy ...
# 18       Faint sudsy head with some with some dissipati...
# 19       A new arrival to the West TN area... \t\tPours...
# 20       Sampled 10/30/11 - Transferring the notes.\t\t...
# 21       This is my first rauchbier. \tPours a burnt am...
# 22       A: Pours a rich, ruby color, clear. Maybe a fi...
# 23       Pours a mahogany color, rich, with a tan head....
# 24       Pours light caramel brown with reddish highlig...
# 25       Poured a slightly cloudy deep amber/red color ...
# 26       Big thanks to N2168 for knocking this off my w...
# 27       On tap last night at the Caldera Tap House.\t\...
# 28       22 oz. Think I picked this up in Chicago Binny...
# 29       Poured into a 1/2 liter stein a deep rich ambe...
# ...                                                    ...
# 1269261  Served in a standard pint glass. Poured a hazy...
# 1269262  Clear amber with a beautifully dense white hea...
# 1269263  I'm always a bit apprehensive when it comes to...
# 1269264  Got this at the LCBO\t\tFrom a bottle into a p...
# 1269265  Appearance: cloudy amber, with a creamy head t...
# 1269266  Nice malt aroma of familiar British style. Sli...
# 1269267  A: Pours a transparent gold color that creates...
# 1269268  16oz nitro can poured into a shaker pint glass...
# 1269269  Another entry from NSLC's 'Beers of the World'...
# 1269270  Pours a oft-amber color. Scents of roasted nut...
# 1269271  A: Pours a dark golden red with a thick, cream...
# 1269272  12 oz into a pint\t\tA - Pours an extremely cl...
# 1269273  Has a nice amber color with a beautiful smooth...
# 1269274  On tap at Boulevard Tavern, Brooklyn, NY.\t\tA...
# 1269275  From the nitro can, this is basically the same...
# 1269276  It is red amber with a fairly creamy off-white...
# 1269277  Serving type - nitro can poured into a mug.\t\...
# 1269278  Sampled from a 12oz bottle in a standard pint ...
# 1269279  A: Nice copper color with one finger tan head ...
# 1269280  Serveing: On Tap at The Curragh Irish Pub\tApp...
# 1269281  I thought this classic English Ale would be on...
# 1269282  This one is a little malty on the nose, with a...
# 1269283  Reddish orange in color, it comes in a clear b...
# 1269284  I decided to try one of these since I own an M...
# 1269285  A clear copper color body with a small white h...
# 1269286  Drank this out of a bottle. My first pale ale ...
# 1269287  A-Pours cloudy at first like all nitro cans, b...
# 1269288  Poured into a pint glass.\t\tA: Pours a clear ...
# 1269289  Pours a clear whiskey-amber color with some wh...
# 1269290  Poured this 14.9 oz. nitro can into a British ...
#
# [1269291 rows x 14 columns]
